# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../Data/AQI and Lat Long of Countries.csv")
df
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                        Brazil  Presidente Dutra         41         Good
# 3                         Italy   Priolo Gargallo         66     Moderate
# 4                        Poland         Przasnysz         34         Good
# ...                         ...               ...        ...          ...
# 16690  United States of America  Highland Springs         54     Moderate
# 16691                  Slovakia            Martin         71     Moderate
# 16692                  Slovakia            Martin         71     Moderate
# 16693                    France            Sceaux         50         Good
# 16694  United States of America       Westerville         71     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
df.isnull().sum()
# Out:
# Country               302
# City                    0
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# lat                     0
# lng                     0
# dtype: int64

# %%
df['Country'] = df['Country'].fillna('Unknown')

# %%
df = df.drop_duplicates()
df
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                        Brazil  Presidente Dutra         41         Good
# 3                         Italy   Priolo Gargallo         66     Moderate
# 4                        Poland         Przasnysz         34         Good
# ...                         ...               ...        ...          ...
# 16690  United States of America  Highland Springs         54     Moderate
# 16691                  Slovakia            Martin         71     Moderate
# 16692                  Slovakia            Martin         71     Moderate
# 16693                    France            Sceaux         50         Good
# 16694  United States of America       Westerville         71     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
df.isnull().sum()
# Out:
# Country               0
# City                  0
# AQI Value             0
# AQI Category          0
# CO AQI Value          0
# CO AQI Category       0
# Ozone AQI Value       0
# Ozone AQI Category    0
# NO2 AQI Value         0
# NO2 AQI Category      0
# PM2.5 AQI Value       0
# PM2.5 AQI Category    0
# lat                   0
# lng                   0
# dtype: int64

# %%
df.nunique()
# Out:
# Country                 175
# City                  14229
# AQI Value               282
# AQI Category              6
# CO AQI Value             31
# CO AQI Category           3
# Ozone AQI Value         203
# Ozone AQI Category        5
# NO2 AQI Value            56
# NO2 AQI Category          2
# PM2.5 AQI Value         298
# PM2.5 AQI Category        6
# lat                   14135
# lng                   14896
# dtype: int64

# %%
df['AQI Category'].unique()
# Out:
# array(['Moderate', 'Good', 'Unhealthy', 'Very Unhealthy',
#        'Unhealthy for Sensitive Groups', 'Hazardous'], dtype=object)

# %%
df = df.replace('Good',1)
df = df.replace('Moderate',2)
df = df.replace('Unhealthy',3)
df = df.replace('Very Unhealthy',4)
df = df.replace('Unhealthy for Sensitive Groups',5)
df = df.replace('Hazardous',6)
# Out:
# C:\Users\NAYAN ADHIKARI\AppData\Local\Temp\ipykernel_6508\3194555296.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace('Moderate',2)
# C:\Users\NAYAN ADHIKARI\AppData\Local\Temp\ipykernel_6508\3194555296.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace('Unhealthy for Sensitive Groups',5)
# ...

# %%
df.nunique()
# Out:
# Country                 175
# City                  14229
# AQI Value               282
# AQI Category              6
# CO AQI Value             31
# CO AQI Category           3
# Ozone AQI Value         203
# Ozone AQI Category        5
# NO2 AQI Value            56
# NO2 AQI Category          2
# PM2.5 AQI Value         298
# PM2.5 AQI Category        6
# lat                   14135
# lng                   14896
# dtype: int64

# %%
df
# Out:
#                         Country              City  AQI Value  AQI Category  \
# 0            Russian Federation        Praskoveya         51             2
# 1                        Brazil  Presidente Dutra         41             1
# 2                        Brazil  Presidente Dutra         41             1
# 3                         Italy   Priolo Gargallo         66             2
# 4                        Poland         Przasnysz         34             1
# ...                         ...               ...        ...           ...
# 16690  United States of America  Highland Springs         54             2
# 16691                  Slovakia            Martin         71             2
# 16692                  Slovakia            Martin         71             2
# 16693                    France            Sceaux         50             1
# 16694  United States of America       Westerville         71             2
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16695 entries, 0 to 16694
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             16695 non-null  object
#  1   City                16695 non-null  object
#  2   AQI Value           16695 non-null  int64
#  3   AQI Category        16695 non-null  int64
#  4   CO AQI Value        16695 non-null  int64
#  5   CO AQI Category     16695 non-null  int64
#  6   Ozone AQI Value     16695 non-null  int64
#  7   Ozone AQI Category  16695 non-null  int64
#  8   NO2 AQI Value       16695 non-null  int64
#  9   NO2 AQI Category    16695 non-null  int64
#  10  PM2.5 AQI Value     16695 non-null  int64
#  11  PM2.5 AQI Category  16695 non-null  int64
#  12  lat                 16695 non-null  float64
#  13  lng                 16695 non-null  float64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 1.8+ MB

# %%
df.to_csv("../Data/AQI and Lat Long of Countries_cleaned.csv",index= False)
